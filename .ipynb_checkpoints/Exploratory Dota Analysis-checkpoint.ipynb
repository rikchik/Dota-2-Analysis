# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: numpy in e:\python3.10\lib\site-packages (1.23.5)
# Requirement already satisfied: pandas in e:\python3.10\lib\site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in e:\python3.10\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\python3.10\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.21.0 in e:\python3.10\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in e:\python3.10\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Requirement already satisfied: matplotlib in e:\python3.10\lib\site-packages (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\python3.10\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in e:\python3.10\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\python3.10\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\python3.10\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in e:\python3.10\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in e:\python3.10\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in e:\python3.10\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in e:\python3.10\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in e:\python3.10\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in e:\python3.10\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: seaborn in e:\python3.10\lib\site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.17 in e:\python3.10\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in e:\python3.10\lib\site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in e:\python3.10\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\python3.10\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in e:\python3.10\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\python3.10\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\python3.10\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in e:\python3.10\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in e:\python3.10\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in e:\python3.10\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in e:\python3.10\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\python3.10\lib\site-packages (from pandas>=0.25->seaborn) (2020.1)
# Requirement already satisfied: six>=1.5 in e:\python3.10\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.15.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The only relevant data

# %%
regions=pd.read_csv(r"F:\Dota data\Dota Analysis\cluster_regions.csv")
heroes=pd.read_csv(r"F:\Dota data\Dota Analysis\hero_names.csv")
matches=pd.read_csv(r"F:\Dota data\Dota Analysis\match.csv")
patch=pd.read_csv(r"F:\Dota data\Dota Analysis\patch_dates.csv")
players=pd.read_csv(r"F:\Dota data\Dota Analysis\players.csv")

# %% [markdown]
# The different regions for different game servers

# %%
regions.head()
# Out:
#    cluster   region
# 0      111  US WEST
# 1      112  US WEST
# 2      113  US WEST
# 3      121  US EAST
# 4      122  US EAST

# %% [markdown]
# Use cluster column to join on other dataframes

# %%
regions.dtypes
# Out:
# cluster     int64
# region     object
# dtype: object

# %% [markdown]
# The different playable characters, i.e., Heroes

# %%
heroes.head()
# Out:
#                            name  hero_id  localized_name
# 0        npc_dota_hero_antimage        1       Anti-Mage
# 1             npc_dota_hero_axe        2             Axe
# 2            npc_dota_hero_bane        3            Bane
# 3     npc_dota_hero_bloodseeker        4     Bloodseeker
# 4  npc_dota_hero_crystal_maiden        5  Crystal Maiden

# %%
heroes.dtypes
# Out:
# name              object
# hero_id            int64
# localized_name    object
# dtype: object

# %% [markdown]
# Matches for which data have been collected

# %%
matches.head()
# Out:
#    match_id  start_time  duration  tower_status_radiant  tower_status_dire  \
# 0         0  1446750112      2375                  1982                  4
# 1         1  1446753078      2582                     0               1846
# 2         2  1446764586      2716                   256               1972
# 3         3  1446765723      3085                     4               1924
# 4         4  1446796385      1887                  2047                  0
#
#    barracks_status_dire  barracks_status_radiant  first_blood_time  game_mode  \
# 0                     3                       63                 1         22
# 1                    63                        0               221         22
# 2                    63                       48               190         22
# 3                    51                        3                40         22
# 4                     0                       63                58         22
#
#    radiant_win  negative_votes  positive_votes  cluster
# 0         True               0               1      155
# 1        False               0               2      154
# 2        False               0               0      132
# 3        False               0               0      191
# 4         True               0               0      156

# %% [markdown]
# Only relevant fields are match_id,start_time,duration,game_mode,radiant_win,clusterm

# %%
matches.dtypes
# Out:
# match_id                int64
# start_time              int64
# duration                int64
# tower_status_radiant    int64
# tower_status_dire       int64
#                         ...
# game_mode               int64
# radiant_win              bool
# negative_votes          int64
# positive_votes          int64
# cluster                 int64
# Length: 13, dtype: object

# %%
matches=matches[["match_id","start_time","duration","game_mode","radiant_win","cluster"]]

# %%
matches.dtypes
# Out:
# match_id       int64
# start_time     int64
# duration       int64
# game_mode      int64
# radiant_win     bool
# cluster        int64
# dtype: object

# %% [markdown]
# Current Patch. There are sub-patches too but not given any info on those

# %%
patch.head()
# Out:
#              patch_date  name
# 0  2010-12-24T00:00:00Z  6.70
# 1  2011-01-21T00:00:00Z  6.71
# 2  2011-04-27T00:00:00Z  6.72
# 3  2011-12-24T00:00:00Z  6.73
# 4  2012-03-10T00:00:00Z  6.74

# %%
players.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold  gold_spent  gold_per_min  \
# 0         0           0       86            0  3261       10960           347
# 1         0           1       51            1  2954       17760           494
# 2         0           0       83            2   110       12195           350
# 3         0           2       11            3  1179       22505           599
# 4         0           3       67            4  3307       23825           613
#
#    xp_per_min  kills  deaths  ...  unit_order_glyph  \
# 0         362      9       3  ...               NaN
# 1         659     13       3  ...               NaN
# 2         385      0       4  ...               NaN
# 3         605      8       4  ...               1.0
# 4         762     20       3  ...               3.0
#
#    unit_order_eject_item_from_stash  unit_order_cast_rune  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
# 3                               NaN                   NaN
# 4                               NaN                   NaN
#
#   unit_order_ping_ability  unit_order_move_to_direction  unit_order_patrol  \
# 0                     6.0                           NaN                NaN
# 1                    14.0                           NaN                NaN
# 2                    17.0                           NaN                NaN
# 3                    13.0                           NaN                NaN
# 4                    23.0                           NaN                NaN
#
#    unit_order_vector_target_position  unit_order_radar  \
# 0                                NaN               NaN
# 1                                NaN               NaN
# 2                                NaN               NaN
# 3                                NaN               NaN
# 4                                NaN               NaN
#
#    unit_order_set_item_combine_lock  unit_order_continue
# 0                               NaN                  NaN
# 1                               NaN                  NaN
# 2                               NaN                  NaN
# 3                               NaN                  NaN
# 4                               NaN                  NaN
#
# [5 rows x 73 columns]

# %%
pd.set_option('display.max_rows', None)
print(players.dtypes)
pd.set_option('display.max_rows', 10)
print(players.columns)
# Out:
# match_id                               int64
# account_id                             int64
# hero_id                                int64
# player_slot                            int64
# gold                                   int64
# gold_spent                             int64
# gold_per_min                           int64
# xp_per_min                             int64
# kills                                  int64
# deaths                                 int64
# assists                                int64
# denies                                 int64
# last_hits                              int64
# stuns                                 object
# hero_damage                            int64
# hero_healing                           int64
# tower_damage                           int64
# item_0                                 int64
# item_1                                 int64
# item_2                                 int64
# item_3                                 int64
# item_4                                 int64
# item_5                                 int64
# level                                  int64
# leaver_status                          int64
# xp_hero                              float64
# xp_creep                             float64
# xp_roshan                            float64
# xp_other                             float64
# gold_other                           float64
# gold_death                           float64
# gold_buyback                         float64
# gold_abandon                         float64
# gold_sell                            float64
# gold_destroying_structure            float64
# gold_killing_heros                   float64
# gold_killing_creeps                  float64
# gold_killing_roshan                  float64
# gold_killing_couriers                float64
# unit_order_none                      float64
# unit_order_move_to_position          float64
# unit_order_move_to_target            float64
# unit_order_attack_move               float64
# unit_order_attack_target             float64
# unit_order_cast_position             float64
# unit_order_cast_target               float64
# unit_order_cast_target_tree          float64
# unit_order_cast_no_target            float64
# unit_order_cast_toggle               float64
# unit_order_hold_position             float64
# unit_order_train_ability             float64
# unit_order_drop_item                 float64
# unit_order_give_item                 float64
# unit_order_pickup_item               float64
# unit_order_pickup_rune               float64
# unit_order_purchase_item             float64
# unit_order_sell_item                 float64
# unit_order_disassemble_item          float64
# unit_order_move_item                 float64
# unit_order_cast_toggle_auto          float64
# unit_order_stop                      float64
# unit_order_taunt                     float64
# unit_order_buyback                   float64
# unit_order_glyph                     float64
# unit_order_eject_item_from_stash     float64
# unit_order_cast_rune                 float64
# unit_order_ping_ability              float64
# unit_order_move_to_direction         float64
# unit_order_patrol                    float64
# unit_order_vector_target_position    float64
# unit_order_radar                     float64
# unit_order_set_item_combine_lock     float64
# unit_order_continue                  float64
# dtype: object
# Index(['match_id', 'account_id', 'hero_id', 'player_slot', 'gold',
#        'gold_spent', 'gold_per_min', 'xp_per_min', 'kills', 'deaths',
#        'assists', 'denies', 'last_hits', 'stuns', 'hero_damage',
#        'hero_healing', 'tower_damage', 'item_0', 'item_1', 'item_2', 'item_3',
#        'item_4', 'item_5', 'level', 'leaver_status', 'xp_hero', 'xp_creep',
#        'xp_roshan', 'xp_other', 'gold_other', 'gold_death', 'gold_buyback',
#        'gold_abandon', 'gold_sell', 'gold_destroying_structure',
#        'gold_killing_heros', 'gold_killing_creeps', 'gold_killing_roshan',
#        'gold_killing_couriers', 'unit_order_none',
#        'unit_order_move_to_position', 'unit_order_move_to_target',
#        'unit_order_attack_move', 'unit_order_attack_target',
#        'unit_order_cast_position', 'unit_order_cast_target',
#        'unit_order_cast_target_tree', 'unit_order_cast_no_target',
#        'unit_order_cast_toggle', 'unit_order_hold_position',
#        'unit_order_train_ability', 'unit_order_drop_item',
#        'unit_order_give_item', 'unit_order_pickup_item',
#        'unit_order_pickup_rune', 'unit_order_purchase_item',
#        'unit_order_sell_item', 'unit_order_disassemble_item',
#        'unit_order_move_item', 'unit_order_cast_toggle_auto',
#        'unit_order_stop', 'unit_order_taunt', 'unit_order_buyback',
#        'unit_order_glyph', 'unit_order_eject_item_from_stash',
#        'unit_order_cast_rune', 'unit_order_ping_ability',
#        'unit_order_move_to_direction', 'unit_order_patrol',
#        'unit_order_vector_target_position', 'unit_order_radar',
#        'unit_order_set_item_combine_lock', 'unit_order_continue'],
#       dtype='object')

# %% [markdown]
# Relevant columns ['match_id', 'account_id', 'hero_id', 'player_slot', 'gold_per_min', 'xp_per_min', 'kills', 'deaths',
#        'tower_damage']

# %%
players=players[['match_id', 'account_id', 'hero_id', 'player_slot', 'gold_per_min', 'xp_per_min', 'kills', 'deaths', 'tower_damage', 'item_0', 'item_1' ,'item_2','item_3','item_4','item_5']]
players.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold_per_min  xp_per_min  \
# 0         0           0       86            0           347         362
# 1         0           1       51            1           494         659
# 2         0           0       83            2           350         385
# 3         0           2       11            3           599         605
# 4         0           3       67            4           613         762
#
#    kills  deaths  tower_damage  item_0  item_1  item_2  item_3  item_4  item_5
# 0      9       3           143     180      37      73      56     108       0
# 1     13       3           423      46      63     119     102      24     108
# 2      0       4           399      48      60      59     108      65       0
# 3      8       4          6055      63     147     154     164      79     160
# 4     20       3          1833     114      92     147       0     137      63

# %%
players.dtypes
# Out:
# match_id        int64
# account_id      int64
# hero_id         int64
# player_slot     int64
# gold_per_min    int64
#                 ...
# item_1          int64
# item_2          int64
# item_3          int64
# item_4          int64
# item_5          int64
# Length: 15, dtype: object

# %% [markdown]
# All int but hero_id is categorical. Now check for na values

# %%
print(f"Missing Values in regions:{regions.isnull().values.any()}")
print(f"Missing Values in heroes:{heroes.isnull().values.any()}")
print(f"Missing Values in regions:{matches.isnull().values.any()}")
print(f"Missing Values in regions:{patch.isnull().values.any()}")
print(f"Missing Values in regions:{players.isnull().values.any()}")
# Out:
# Missing Values in regions:False
# Missing Values in heroes:False
# Missing Values in regions:False
# Missing Values in regions:False
# Missing Values in regions:False

# %% [markdown]
# Questions to Ask:-
# 1. Which region plays most dota?
# 2. Which hero is most played?
# 3. Which hero accumulates the most gold?
# 4. which hero accumulates the most exp?
# 5. Which hero kills most?
# 6. Which hero dies most?
# 7. What hero was good at each patch?(Time series)
# 8. What hero was worst at each patch?(Tim Series)
# 9. Which big item is usually most bought per patch?
# 10. Which big item is usually least bought per patch?
# 11. Which game mode is played most?
# 12. What heroes storm spirit counters?
# 13. What heroes counter storm spirit?

# %% [markdown]
# ## Which region plays most dota?

# %%
df=pd.merge(matches,regions,left_on="cluster",right_on="cluster",how="left")
df.head()
# Out:
#    match_id  start_time  duration  game_mode  radiant_win  cluster     region
# 0         0  1446750112      2375         22         True      155  SINGAPORE
# 1         1  1446753078      2582         22        False      154  SINGAPORE
# 2         2  1446764586      2716         22        False      132     EUROPE
# 3         3  1446765723      3085         22        False      191    AUSTRIA
# 4         4  1446796385      1887         22         True      156  SINGAPORE

# %%
df.replace({"EUROPE":"EU","SINGAPORE":"SNG","AUSTRALIA":"AUS","AUSTRIA":"AST","BRAZIL":"BRZ","STOCKHOLM":"STK",
            'PW TELECOM SHANGHAI':"SHNG",'PW TELECOM ZHEJIANG':"ZHE",'PW TELECOM GUANGDONG':"GNG","PW UNICOM":"UNI"},inplace=True)
df["region"].value_counts().index
# Out:
# Index(['EU', 'US EAST', 'SNG', 'US WEST', 'AUS', 'AST', 'BRZ', 'STK', 'SHNG',
#        'ZHE', 'GNG', 'JAPAN', 'UNI', 'DUBAI', 'CHILE'],
#       dtype='object')

# %%
sns.countplot(df,x="region",order=df["region"].value_counts().index).set(title='Most played regions')
sns.set_theme(rc={'figure.figsize':(15,12)})

# %% [markdown]
# ## Which hero is most played?

# %%
df=pd.merge(players, heroes[["hero_id","localized_name"]],left_on="hero_id",right_on="hero_id",how="left")
df
# Out:
#         match_id  account_id  hero_id  player_slot  gold_per_min  xp_per_min  \
# 0              0           0       86            0           347         362
# 1              0           1       51            1           494         659
# 2              0           0       83            2           350         385
# 3              0           2       11            3           599         605
# 4              0           3       67            4           613         762
# ...          ...         ...      ...          ...           ...         ...
# 499995     49999           0      100          128           468         626
# 499996     49999           0        9          129           507         607
# 499997     49999           0       90          130           371         404
# 499998     49999           0       73          131           780         703
# 499999     49999      158360       53          132           520         533
#
#         kills  deaths  tower_damage  item_0  item_1  item_2  item_3  item_4  \
# 0           9       3           143     180      37      73      56     108
# 1          13       3           423      46      63     119     102      24
# 2           0       4           399      48      60      59     108      65
# 3           8       4          6055      63     147     154     164      79
# 4          20       3          1833     114      92     147       0     137
# ...       ...     ...           ...     ...     ...     ...     ...     ...
# 499995     16       9          1227     249      41       0      50     141
# 499996     12       6          2269     135      63     166      30      36
# 499997      5       3            87      79      48     152     108     102
# 499998      8       6          2851     249     154     112      48     114
# 499999      6       6          5747       1     158      48      51      40
#
#         item_5       localized_name
# 0            0               Rubick
# 1          108            Clockwerk
# 2            0     Treant Protector
# 3          160         Shadow Fiend
# 4           63              Spectre
# ...        ...                  ...
# 499995     168                 Tusk
# 499996     139               Mirana
# 499997     117  Keeper of the Light
# 499998     137            Alchemist
# 499999     141     Nature's Prophet
#
# [500000 rows x 16 columns]

# %%
sns.countplot(df,x="localized_name",order=df["localized_name"].value_counts().index[:10]).set(title="Most played heroes")
sns.set_theme(rc={'figure.figsize':(15,12)})

# %% [markdown]
# ## Which hero accumulates the most gold?

# %%
df=pd.merge(players,heroes[["hero_id","localized_name"]],left_on="hero_id",right_on="hero_id",how="left")
df.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold_per_min  xp_per_min  \
# 0         0           0       86            0           347         362
# 1         0           1       51            1           494         659
# 2         0           0       83            2           350         385
# 3         0           2       11            3           599         605
# 4         0           3       67            4           613         762
#
#    kills  deaths  tower_damage  item_0  item_1  item_2  item_3  item_4  \
# 0      9       3           143     180      37      73      56     108
# 1     13       3           423      46      63     119     102      24
# 2      0       4           399      48      60      59     108      65
# 3      8       4          6055      63     147     154     164      79
# 4     20       3          1833     114      92     147       0     137
#
#    item_5    localized_name
# 0       0            Rubick
# 1     108         Clockwerk
# 2       0  Treant Protector
# 3     160      Shadow Fiend
# 4      63           Spectre

# %%
top_gold=df.groupby("localized_name")["gold_per_min"].mean().sort_values(ascending=False)

# %%
sns.barplot(x=top_gold.index[:10],y=top_gold[:10]).set(title="Highest GPM Hero")
sns.set_theme(rc={'figure.figsize':(15,12)})

# %% [markdown]
# ## Which hero accumulates most exp?

# %%
df=pd.merge(players,heroes[["hero_id","localized_name"]],left_on="hero_id",right_on="hero_id",how="left")
df.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold_per_min  xp_per_min  \
# 0         0           0       86            0           347         362
# 1         0           1       51            1           494         659
# 2         0           0       83            2           350         385
# 3         0           2       11            3           599         605
# 4         0           3       67            4           613         762
#
#    kills  deaths  tower_damage  item_0  item_1  item_2  item_3  item_4  \
# 0      9       3           143     180      37      73      56     108
# 1     13       3           423      46      63     119     102      24
# 2      0       4           399      48      60      59     108      65
# 3      8       4          6055      63     147     154     164      79
# 4     20       3          1833     114      92     147       0     137
#
#    item_5    localized_name
# 0       0            Rubick
# 1     108         Clockwerk
# 2       0  Treant Protector
# 3     160      Shadow Fiend
# 4      63           Spectre

# %%
top_exp=df.groupby("localized_name")["xp_per_min"].mean().sort_values(ascending=False)

# %%
sns.barplot(x=top_exp.index[:10],y=top_exp[:10]).set(title="Highest XPM Hero")
sns.set_theme(rc={'figure.figsize':(15,12)})

# %% [markdown]
# ## Which hero kills most?

# %%
df=pd.merge(players,heroes[["hero_id","localized_name"]],left_on="hero_id",right_on="hero_id",how="left")
df.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold_per_min  xp_per_min  \
# 0         0           0       86            0           347         362
# 1         0           1       51            1           494         659
# 2         0           0       83            2           350         385
# 3         0           2       11            3           599         605
# 4         0           3       67            4           613         762
#
#    kills  deaths  tower_damage  item_0  item_1  item_2  item_3  item_4  \
# 0      9       3           143     180      37      73      56     108
# 1     13       3           423      46      63     119     102      24
# 2      0       4           399      48      60      59     108      65
# 3      8       4          6055      63     147     154     164      79
# 4     20       3          1833     114      92     147       0     137
#
#    item_5    localized_name
# 0       0            Rubick
# 1     108         Clockwerk
# 2       0  Treant Protector
# 3     160      Shadow Fiend
# 4      63           Spectre

# %%
top_kills=df.groupby("localized_name")["kills"].mean().sort_values(ascending=False)

# %%
sns.barplot(x=top_kills.index[:10],y=top_kills[:10]).set(title="Highest kills Hero")
sns.set_theme(rc={'figure.figsize':(15,12)})

# %% [markdown]
# ## Which hero dies most?

# %%
df=pd.merge(players,heroes[["hero_id","localized_name"]],left_on="hero_id",right_on="hero_id",how="left")
df.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold_per_min  xp_per_min  \
# 0         0           0       86            0           347         362
# 1         0           1       51            1           494         659
# 2         0           0       83            2           350         385
# 3         0           2       11            3           599         605
# 4         0           3       67            4           613         762
#
#    kills  deaths  tower_damage  item_0  item_1  item_2  item_3  item_4  \
# 0      9       3           143     180      37      73      56     108
# 1     13       3           423      46      63     119     102      24
# 2      0       4           399      48      60      59     108      65
# 3      8       4          6055      63     147     154     164      79
# 4     20       3          1833     114      92     147       0     137
#
#    item_5    localized_name
# 0       0            Rubick
# 1     108         Clockwerk
# 2       0  Treant Protector
# 3     160      Shadow Fiend
# 4      63           Spectre

# %%
top_deaths=df.groupby("localized_name")["deaths"].mean().sort_values(ascending=False)

# %%
sns.barplot(x=top_deaths.index[:10],y=top_deaths[:10]).set(title="Highest deaths Hero")
sns.set_theme(rc={'figure.figsize':(15,12)})

# %% [markdown]
# ## What hero was good at each patch?(Time series)

# %%
df=pd.merge(players,matches,left_on="match_id",right_on="match_id",how="right")
df.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold_per_min  xp_per_min  \
# 0         0           0       86            0           347         362
# 1         0           1       51            1           494         659
# 2         0           0       83            2           350         385
# 3         0           2       11            3           599         605
# 4         0           3       67            4           613         762
#
#    kills  deaths  tower_damage  item_0  item_1  item_2  item_3  item_4  \
# 0      9       3           143     180      37      73      56     108
# 1     13       3           423      46      63     119     102      24
# 2      0       4           399      48      60      59     108      65
# 3      8       4          6055      63     147     154     164      79
# 4     20       3          1833     114      92     147       0     137
#
#    item_5  start_time  duration  game_mode  radiant_win  cluster
# 0       0  1446750112      2375         22         True      155
# 1     108  1446750112      2375         22         True      155
# 2       0  1446750112      2375         22         True      155
# 3     160  1446750112      2375         22         True      155
# 4      63  1446750112      2375         22         True      155

# %%
df["start_time_date_time"]=pd.to_datetime(df['start_time'],unit='s')
df["start_time_date_time"].sort_values()
df.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold_per_min  xp_per_min  \
# 0         0           0       86            0           347         362
# 1         0           1       51            1           494         659
# 2         0           0       83            2           350         385
# 3         0           2       11            3           599         605
# 4         0           3       67            4           613         762
#
#    kills  deaths  tower_damage  item_0  ...  item_2  item_3  item_4  item_5  \
# 0      9       3           143     180  ...      73      56     108       0
# 1     13       3           423      46  ...     119     102      24     108
# 2      0       4           399      48  ...      59     108      65       0
# 3      8       4          6055      63  ...     154     164      79     160
# 4     20       3          1833     114  ...     147       0     137      63
#
#    start_time  duration  game_mode  radiant_win  cluster  start_time_date_time
# 0  1446750112      2375         22         True      155   2015-11-05 19:01:52
# 1  1446750112      2375         22         True      155   2015-11-05 19:01:52
# 2  1446750112      2375         22         True      155   2015-11-05 19:01:52
# 3  1446750112      2375         22         True      155   2015-11-05 19:01:52
# 4  1446750112      2375         22         True      155   2015-11-05 19:01:52
#
# [5 rows x 21 columns]

# %%
patch['next_date']=patch['patch_date'].shift(-1)
patch.at[18,"next_date"]=patch.loc[18]["patch_date"]
patch.rename(columns={"name":"patch_name"},inplace=True)
patch
# Out:
#               patch_date  patch_name             next_date
# 0   2010-12-24T00:00:00Z        6.70  2011-01-21T00:00:00Z
# 1   2011-01-21T00:00:00Z        6.71  2011-04-27T00:00:00Z
# 2   2011-04-27T00:00:00Z        6.72  2011-12-24T00:00:00Z
# 3   2011-12-24T00:00:00Z        6.73  2012-03-10T00:00:00Z
# 4   2012-03-10T00:00:00Z        6.74  2012-09-30T00:00:00Z
# ..                   ...         ...                   ...
# 14  2015-04-30T21:00:00Z        6.84  2015-09-24T20:00:00Z
# 15  2015-09-24T20:00:00Z        6.85  2015-12-16T20:00:00Z
# 16  2015-12-16T20:00:00Z        6.86  2016-04-26T01:00:00Z
# 17  2016-04-26T01:00:00Z        6.87  2016-06-12T08:00:00Z
# 18  2016-06-12T08:00:00Z        6.88  2016-06-12T08:00:00Z
#
# [19 rows x 3 columns]

# %%
patch.index = pd.IntervalIndex.from_arrays(patch['patch_date'],patch['next_date'],closed='left')
df['patch_name'] = df_1['timestamp'].apply(lambda x : df_2.iloc[df_2.index.get_loc(x)]['event'])
